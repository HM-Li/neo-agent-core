# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Basics

# %%
from neo.tools import Tool

# %%
def test(haha: str):
    """haha"""
    return "weather"

test = Tool(func=test)

# %%
test.params

# %% [markdown]
# # Image Gen

# %%
from neo.tools.image_gen.openai import agenerate_image

test = await agenerate_image(prompt="a cat")

# %%
from PIL import Image
import io
image = Image.open(io.BytesIO(test.data))
image.show()

# %%
from neo.models.providers.openai import OpenAIResponseModel

model = OpenAIResponseModel(model="gpt-4o")

# %%
from neo.contexts import Context
c = Context(contents=test)

# %%
thread = await model.acreate(user_input=test)

# %%
thread.display()

# %% [markdown]
# # Transcription

# %%
from neo.tools.speech.openai import aspeech2text

# %%
audio_url = "https://cdn.openai.com/API/docs/audio/alloy.wav"

# %%
from neo.types.contents import AudioContent

# %%
audio = AudioContent(data=audio_url)

# %%
test = await aspeech2text(audio=audio)
