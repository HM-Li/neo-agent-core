# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Mistral

# %%
from neo.models.providers.mistral import MistralModel
###
# Models
# magistral-small-2506: free, 24B
# ministral-3b-2410: best edge model, 3B
###
model = MistralModel(model="ministral-3b-2410", 
                 instruction="talk like a german shepherd", 
                 )
test = await model.acreate("hi")

# %%
test.display()
