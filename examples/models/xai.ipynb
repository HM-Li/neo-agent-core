# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # XAI

# %%
def get_weather(location: str):
    """Get current temperature for a given location."""
    # raise ValueError("connection issue. Please try again later.")  # Simulating an error for demonstration
    return f"The current temperature in {location} is 72°F."

# %%
from neo.models.providers.xai import XAIModel
from neo.tools.internal_tools.xai import WebSearch, SearchParameters

model = XAIModel(model="grok-3-mini", 
                 instruction="talk like a german shepherd", 
                 tools=[WebSearch(search_parameters=SearchParameters(mode="on"))]
                 )
test = await model.acreate("Use live information online to answer: What are the hottest topics on the X platform right now?")

# %%
test.display()
