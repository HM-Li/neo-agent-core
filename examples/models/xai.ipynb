# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # XAI

# %%
from neo.models.providers.xai import XAIModel
model = XAIModel(model="grok-2", instruction="talk like a german shepherd")
test = await model.acreate("hi")

# %%
test.display()

# %%
await model.acreate("hi", base_thread=test)

# %%
test.display()
